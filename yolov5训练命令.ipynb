# %% [markdown]
# <a href="https://colab.research.google.com/github/herruiqi/Colab-/blob/main/yolov5%E8%AE%AD%E7%BB%83%E5%91%BD%E4%BB%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive"
os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /content/drive
# ['yolov5训练命令.ipynb']

# %%
# !rm -rf /content/sample_data

# %%
# %cd /content/drive/MyDrive

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/drive/MyDrive/yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 39.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...

# %%
#执行训练命令，train.py
# !python train.py --rect --data=data/coco128.yaml
# Out:
# 2023-10-24 13:35:32.235123: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-24 13:35:32.235182: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-24 13:35:32.235220: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py
# Out:
# detect: weights=/content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt, source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-228-g4d687c8 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/2 /content/drive/MyDrive/yolov5/data/images/bus.jpg: 640x480 3 persons, 1 bus, 42.5ms
# image 2/2 /content/drive/MyDrive/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 1 cell phone, 42.8ms
# Speed: 0.4ms pre-process, 42.6ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# ...
